# %%
import pandas as pd
import numpy as np
import seaborn as sns
import ipywidgets as ipy

# %%
WISCONSIN_DATASET = "https://raw.githubusercontent.com/reddyprasade/Machine-Learning-Problems-DataSets/d9d8bc1858a7073cf1c18799d797491e9805ea2b/Classification/Breast%20cancer%20wisconsin.csv"

wisconsin_breast_cancer_data = pd.read_csv(WISCONSIN_DATASET, index_col=[0])

pd.set_option('display.max_columns', wisconsin_breast_cancer_data.shape[1] + 1)

wisconsin_breast_cancer_data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      symmetry_mean  fractal_dimension_mean  radius_se  texture_se  \
# 0           0.2419                 0.07871     1.0950      0.9053
# 1           0.1812                 0.05667     0.5435      0.7339
# 2           0.2069                 0.05999     0.7456      0.7869
# 3           0.2597                 0.09744     0.4956      1.1560
# 4           0.1809                 0.05883     0.7572      0.7813
# ..             ...                     ...        ...         ...
# 564         0.1726                 0.05623     1.1760      1.2560
# 565         0.1752                 0.05533     0.7655      2.4630
# 566         0.1590                 0.05648     0.4564      1.0750
# 567         0.2397                 0.07016     0.7260      1.5950
# 568         0.1587                 0.05884     0.3857      1.4280
#
#      perimeter_se  area_se  smoothness_se  compactness_se  concavity_se  \
# 0           8.589   153.40       0.006399         0.04904       0.05373
# 1           3.398    74.08       0.005225         0.01308       0.01860
# 2           4.585    94.03       0.006150         0.04006       0.03832
# 3           3.445    27.23       0.009110         0.07458       0.05661
# 4           5.438    94.44       0.011490         0.02461       0.05688
# ..            ...      ...            ...             ...           ...
# 564         7.673   158.70       0.010300         0.02891       0.05198
# 565         5.203    99.04       0.005769         0.02423       0.03950
# 566         3.425    48.55       0.005903         0.03731       0.04730
# 567         5.772    86.22       0.006522         0.06158       0.07117
# 568         2.548    19.15       0.007189         0.00466       0.00000
#
#      concave points_se  symmetry_se  fractal_dimension_se  radius_worst  \
# 0              0.01587      0.03003              0.006193        25.380
# 1              0.01340      0.01389              0.003532        24.990
# 2              0.02058      0.02250              0.004571        23.570
# 3              0.01867      0.05963              0.009208        14.910
# 4              0.01885      0.01756              0.005115        22.540
# ..                 ...          ...                   ...           ...
# 564            0.02454      0.01114              0.004239        25.450
# 565            0.01678      0.01898              0.002498        23.690
# 566            0.01557      0.01318              0.003892        18.980
# 567            0.01664      0.02324              0.006185        25.740
# 568            0.00000      0.02676              0.002783         9.456
#
#      texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0            17.33           184.60      2019.0           0.16220
# 1            23.41           158.80      1956.0           0.12380
# 2            25.53           152.50      1709.0           0.14440
# 3            26.50            98.87       567.7           0.20980
# 4            16.67           152.20      1575.0           0.13740
# ..             ...              ...         ...               ...
# 564          26.40           166.10      2027.0           0.14100
# 565          38.25           155.00      1731.0           0.11660
# 566          34.12           126.70      1124.0           0.11390
# 567          39.42           184.60      1821.0           0.16500
# 568          30.37            59.16       268.6           0.08996
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0              0.66560           0.7119                0.2654          0.4601
# 1              0.18660           0.2416                0.1860          0.2750
# 2              0.42450           0.4504                0.2430          0.3613
# 3              0.86630           0.6869                0.2575          0.6638
# 4              0.20500           0.4000                0.1625          0.2364
# ..                 ...              ...                   ...             ...
# 564            0.21130           0.4107                0.2216          0.2060
# 565            0.19220           0.3215                0.1628          0.2572
# 566            0.30940           0.3403                0.1418          0.2218
# 567            0.86810           0.9387                0.2650          0.4087
# 568            0.06444           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst
# 0                    0.11890
# 1                    0.08902
# 2                    0.08758
# 3                    0.17300
# 4                    0.07678
# ..                       ...
# 564                  0.07115
# 565                  0.06637
# 566                  0.07820
# 567                  0.12400
# 568                  0.07039
#
# [569 rows x 32 columns]

# %%
print(f"Number of rows: {wisconsin_breast_cancer_data.shape[0]}")
print(f"Number of columns: {wisconsin_breast_cancer_data.shape[1]}")

no_nans_present = np.all(
    wisconsin_breast_cancer_data.isna().sum() == 0
)

print(f"No NaNs present in the dataset: {no_nans_present}")

wisconsin_breast_cancer_data.describe()
# Out:
# Number of rows: 569
# Number of columns: 32
# No NaNs present in the dataset: True
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean  fractal_dimension_mean   radius_se  texture_se  \
# count     569.000000              569.000000  569.000000  569.000000
# mean        0.181162                0.062798    0.405172    1.216853
# std         0.027414                0.007060    0.277313    0.551648
# min         0.106000                0.049960    0.111500    0.360200
# 25%         0.161900                0.057700    0.232400    0.833900
# 50%         0.179200                0.061540    0.324200    1.108000
# 75%         0.195700                0.066120    0.478900    1.474000
# max         0.304000                0.097440    2.873000    4.885000
#
#        perimeter_se     area_se  smoothness_se  compactness_se  concavity_se  \
# count    569.000000  569.000000     569.000000      569.000000    569.000000
# mean       2.866059   40.337079       0.007041        0.025478      0.031894
# std        2.021855   45.491006       0.003003        0.017908      0.030186
# min        0.757000    6.802000       0.001713        0.002252      0.000000
# 25%        1.606000   17.850000       0.005169        0.013080      0.015090
# 50%        2.287000   24.530000       0.006380        0.020450      0.025890
# 75%        3.357000   45.190000       0.008146        0.032450      0.042050
# max       21.980000  542.200000       0.031130        0.135400      0.396000
#
#        concave points_se  symmetry_se  fractal_dimension_se  radius_worst  \
# count         569.000000   569.000000            569.000000    569.000000
# mean            0.011796     0.020542              0.003795     16.269190
# std             0.006170     0.008266              0.002646      4.833242
# min             0.000000     0.007882              0.000895      7.930000
# 25%             0.007638     0.015160              0.002248     13.010000
# 50%             0.010930     0.018730              0.003187     14.970000
# 75%             0.014710     0.023480              0.004558     18.790000
# max             0.052790     0.078950              0.029840     36.040000
#
#        texture_worst  perimeter_worst   area_worst  smoothness_worst  \
# count     569.000000       569.000000   569.000000        569.000000
# mean       25.677223       107.261213   880.583128          0.132369
# std         6.146258        33.602542   569.356993          0.022832
# min        12.020000        50.410000   185.200000          0.071170
# 25%        21.080000        84.110000   515.300000          0.116600
# 50%        25.410000        97.660000   686.500000          0.131300
# 75%        29.720000       125.400000  1084.000000          0.146000
# max        49.540000       251.200000  4254.000000          0.222600
#
#        compactness_worst  concavity_worst  concave points_worst  \
# count         569.000000       569.000000            569.000000
# mean            0.254265         0.272188              0.114606
# std             0.157336         0.208624              0.065732
# min             0.027290         0.000000              0.000000
# 25%             0.147200         0.114500              0.064930
# 50%             0.211900         0.226700              0.099930
# 75%             0.339100         0.382900              0.161400
# max             1.058000         1.252000              0.291000
#
#        symmetry_worst  fractal_dimension_worst
# count      569.000000               569.000000
# mean         0.290076                 0.083946
# std          0.061867                 0.018061
# min          0.156500                 0.055040
# 25%          0.250400                 0.071460
# 50%          0.282200                 0.080040
# 75%          0.317900                 0.092080
# max          0.663800                 0.207500

# %%
numeric_mean_features = wisconsin_breast_cancer_data[
    wisconsin_breast_cancer_data.columns[
        wisconsin_breast_cancer_data.columns.str.contains('mean')
    ]
]

def plot_violin_against_diagnosis(feature):
    feature_name = feature.replace('_', ' ').title()
    ax = sns.violinplot(x="diagnosis", y=feature, data=wisconsin_breast_cancer_data)
    ax.set(title=f"{feature_name} against diagnosis")
    ax.set(xlabel="Diagnosis", ylabel=feature_name)

ipy.interact(plot_violin_against_diagnosis, feature=numeric_mean_features)
# Out:
# interactive(children=(Dropdown(description='feature', options=('radius_mean', 'texture_mean', 'perimeter_mean'…
# <function __main__.plot_violin_against_diagnosis(feature)>

# %% [markdown]
# ## Quantities connected with size i.e. tumor radius

# %%
radius_dependent_features = [
    'radius_mean',
    'perimeter_mean',
    'area_mean'
]

# Checking the correlation between the radius columns

radius_correlation = wisconsin_breast_cancer_data[radius_dependent_features].corr()
print(radius_correlation)
radius_correlation_heatmap = sns.heatmap(radius_correlation, annot=True)

# We can safely drop the perimeter and area columns as they are highly correlated with the radius column

numeric_mean_features = numeric_mean_features.drop(columns=['perimeter_mean', 'area_mean'])
# Out:
#                 radius_mean  perimeter_mean  area_mean
# radius_mean        1.000000        0.997855   0.987357
# perimeter_mean     0.997855        1.000000   0.986507
# area_mean          0.987357        0.986507   1.000000

# %% [markdown]
# ## Quantities connected with surface properties

# %%
numeric_mean_features.columns
surface_oriented_features = [
    'texture_mean',
    'smoothness_mean',
    'concavity_mean',
    'concave points_mean'
]

# Checking the correlation between the surface oriented columns

sns.heatmap(wisconsin_breast_cancer_data[surface_oriented_features].corr(), annot=True)

# Concavity and concave points are highly correlated, check the coefficient

concavity_concave_points_correlation = wisconsin_breast_cancer_data[['concavity_mean', 'concave points_mean']].corr()
print(concavity_concave_points_correlation)

# We can safely drop the concave points column as it is highly correlated with the concavity column

try:
    numeric_mean_features = numeric_mean_features.drop(columns=['concave points_mean'])
except KeyError:
    pass

# Plotting the pairplot of the surface oriented features

surface_oriented_features.remove('concave points_mean')
sns.pairplot(numeric_mean_features, vars=surface_oriented_features)
# Out:
#                      concavity_mean  concave points_mean
# concavity_mean             1.000000             0.921391
# concave points_mean        0.921391             1.000000

# %%
# Checking which properties are left

important_features = numeric_mean_features.columns.str.replace('_mean', '')

all_columns_with_features = wisconsin_breast_cancer_data.columns[
    wisconsin_breast_cancer_data.columns.str.contains('|'.join(important_features)) | wisconsin_breast_cancer_data.columns.str.contains('diagnosis')
]

wisconsin_breast_cancer_data = wisconsin_breast_cancer_data[all_columns_with_features]
# Out:
#     diagnosis  radius_mean  texture_mean  smoothness_mean  compactness_mean  \
# 0           M        17.99         10.38          0.11840           0.27760
# 1           M        20.57         17.77          0.08474           0.07864
# 2           M        19.69         21.25          0.10960           0.15990
# 3           M        11.42         20.38          0.14250           0.28390
# 4           M        20.29         14.34          0.10030           0.13280
# ..        ...          ...           ...              ...               ...
# 564         M        21.56         22.39          0.11100           0.11590
# 565         M        20.13         28.25          0.09780           0.10340
# 566         M        16.60         28.08          0.08455           0.10230
# 567         M        20.60         29.33          0.11780           0.27700
# 568         B         7.76         24.54          0.05263           0.04362
#
#      concavity_mean  symmetry_mean  fractal_dimension_mean  radius_se  \
# 0           0.30010         0.2419                 0.07871     1.0950
# 1           0.08690         0.1812                 0.05667     0.5435
# 2           0.19740         0.2069                 0.05999     0.7456
# 3           0.24140         0.2597                 0.09744     0.4956
# 4           0.19800         0.1809                 0.05883     0.7572
# ..              ...            ...                     ...        ...
# 564         0.24390         0.1726                 0.05623     1.1760
# 565         0.14400         0.1752                 0.05533     0.7655
# 566         0.09251         0.1590                 0.05648     0.4564
# 567         0.35140         0.2397                 0.07016     0.7260
# 568         0.00000         0.1587                 0.05884     0.3857
#
#      texture_se  smoothness_se  compactness_se  concavity_se  symmetry_se  \
# 0        0.9053       0.006399         0.04904       0.05373      0.03003
# 1        0.7339       0.005225         0.01308       0.01860      0.01389
# 2        0.7869       0.006150         0.04006       0.03832      0.02250
# 3        1.1560       0.009110         0.07458       0.05661      0.05963
# 4        0.7813       0.011490         0.02461       0.05688      0.01756
# ..          ...            ...             ...           ...          ...
# 564      1.2560       0.010300         0.02891       0.05198      0.01114
# 565      2.4630       0.005769         0.02423       0.03950      0.01898
# 566      1.0750       0.005903         0.03731       0.04730      0.01318
# 567      1.5950       0.006522         0.06158       0.07117      0.02324
# 568      1.4280       0.007189         0.00466       0.00000      0.02676
#
#      fractal_dimension_se  radius_worst  texture_worst  smoothness_worst  \
# 0                0.006193        25.380          17.33           0.16220
# 1                0.003532        24.990          23.41           0.12380
# 2                0.004571        23.570          25.53           0.14440
# 3                0.009208        14.910          26.50           0.20980
# 4                0.005115        22.540          16.67           0.13740
# ..                    ...           ...            ...               ...
# 564              0.004239        25.450          26.40           0.14100
# 565              0.002498        23.690          38.25           0.11660
# 566              0.003892        18.980          34.12           0.11390
# 567              0.006185        25.740          39.42           0.16500
# 568              0.002783         9.456          30.37           0.08996
#
#      compactness_worst  concavity_worst  symmetry_worst  \
# 0              0.66560           0.7119          0.4601
# 1              0.18660           0.2416          0.2750
# 2              0.42450           0.4504          0.3613
# 3              0.86630           0.6869          0.6638
# 4              0.20500           0.4000          0.2364
# ..                 ...              ...             ...
# 564            0.21130           0.4107          0.2060
# 565            0.19220           0.3215          0.2572
# 566            0.30940           0.3403          0.2218
# 567            0.86810           0.9387          0.4087
# 568            0.06444           0.0000          0.2871
#
#      fractal_dimension_worst
# 0                    0.11890
# 1                    0.08902
# 2                    0.08758
# 3                    0.17300
# 4                    0.07678
# ..                       ...
# 564                  0.07115
# 565                  0.06637
# 566                  0.07820
# 567                  0.12400
# 568                  0.07039
#
# [569 rows x 22 columns]

# %% [markdown]
# ## General correlation between quantities

# %%
numeric_values = wisconsin_breast_cancer_data[
    wisconsin_breast_cancer_data.columns[
        wisconsin_breast_cancer_data.columns.str.contains('|'.join(important_features))
    ]
]
means = numeric_values[
    numeric_values.columns[
        numeric_values.columns.str.contains('mean')
    ]
]
means.columns = means.columns.str.replace('_mean', '')

standard_errors = numeric_values[
    numeric_values.columns[
        numeric_values.columns.str.contains('se')
    ]
]
standard_errors.columns = standard_errors.columns.str.replace('_se', '')

worst = numeric_values[
    numeric_values.columns[
        numeric_values.columns.str.contains('worst')
    ]
]
worst.columns = worst.columns.str.replace('_worst', '')

# Showing three heatmaps in one figure
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

sns.heatmap(means.corr(), annot=True, ax=axes[0], cbar=False)
axes[0].set(title="Correlation between mean features")
sns.heatmap(standard_errors.corr(), annot=True, ax=axes[1], cbar=False)
axes[1].set(title="Correlation between standard error features")
axes[1].set(ylabel="")
axes[1].set(yticklabels=[])

sns.heatmap(worst.corr(), annot=True, ax=axes[2], cbar=False)
axes[2].set(title="Correlation between worst features")
axes[2].set(ylabel="")
axes[2].set(yticklabels=[])

fig.tight_layout()
